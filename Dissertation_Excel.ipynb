# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r"/home/amy/PycharmProjects/Dissertation/COMPLETE_PIVOT.xlsx", sheet_name = "TOTAL")

df.head()
# Out:
#    TempID  SiteID Survey_Ref          Modern Name Ancient Name  Local-Easting  \
# 0       1       3    ASI1-10  Horbat Nemal Akhziv          NaN       209578.0
# 1       2       4    ASI1-12    Nahariyya (north)          NaN       209278.0
# 2       3       6     ASI2-9         Mizpe Hanita          NaN       216878.0
# 3       4      12    ASI2-42       Me'arat Kukhim          NaN       218078.0
# 4       5      13    ASI2-43  Magharat el Baiyada          NaN       218078.0
#
#    Local-Northing  Easting-Long  Northing-Lat  SiteSize  ...  \
# 0        771597.0     35.098689     33.039460       3.0  ...
# 1        770697.0     35.095487     33.031342       1.0  ...
# 2        777398.0     35.176820     33.091807       NaN  ...
# 3        776098.0     35.189676     33.080088       NaN  ...
# 4        776298.0     35.189676     33.081891       NaN  ...
#
#                             Period Rainfall Temperature Elevation      Slope  \
# ...

# %%
df.groupby('Period').size()
# Out:
# Period
# Chalcolithic (undifferentiated)         2591
# Early Bronze Age (Undifferentiated)     2517
# Early Bronze I                           853
# Early Bronze II                          612
# Early Bronze II-III                      249
# Early Bronze III                         333
# Early Bronze IV (undifferentiated)      1818
# Early Bronze IVA                          42
# Early Bronze IVB                          53
# Early Bronze IVC                           7
# Early Chalcolithic                        35
# Late Bronze Age (undifferentiated)       914
# Late Bronze I                             87
# Late Bronze II                           116
# Late Bronze III                           13
# Late Chalcolithic                        125
# Middle Bronze Age (undifferentiated)    1109
# Middle Bronze I                          482
# Middle Bronze II                         519
# Middle Bronze II-III                     327
# Middle Bronze III                         59
# ...
